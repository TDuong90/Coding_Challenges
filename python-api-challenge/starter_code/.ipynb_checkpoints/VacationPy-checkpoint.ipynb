# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os

# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
cities = pd.read_csv("../output_data/cities.csv")
cities.head()
del cities["City_ID"]
cities.head()
# Out:
#         City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0  ostrovnoy           2      RU  1558378754        72  68.05   39.51
# 1  mahebourg          75      MU  1558378503        74 -20.41   57.70
# 2    qaanaaq          25      GL  1558378755        73  77.48  -69.36
# 3     zhuhai           0      CN  1558378755        39  40.71  112.04
# 4  cape town          20      ZA  1558378755        76 -33.93   18.42
#
#    Max Temp  Wind Speed
# 0     37.50        7.16
# 1     78.80       11.41
# 2     22.20        2.37
# 3     44.60        4.47
# 4     55.99        8.05

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
cities.columns
cities.dtypes
# Out:
# City           object
# Cloudiness      int64
# Country        object
# Date            int64
# Humidity        int64
# Lat           float64
# Lng           float64
# Max Temp      float64
# Wind Speed    float64
# dtype: object

# %%
humidity_max = cities["Humidity"].max()
humidity_max

locations = cities[["Lat", "Lng"]]

# %%
fig = gmaps.figure(map_type="Hybrid")

heat_layer = gmaps.heatmap_layer(locations, weights=cities["Humidity"],dissipating=False, max_intensity=humidity_max,point_radius=1)
fig.add_layer(heat_layer)
fig
# Out:
# ---------------------------------------------------------------------------
# TraitError                                Traceback (most recent call last)
# <ipython-input-16-88286fd8797a> in <module>
# ----> 1 fig = gmaps.figure(map_type="Hybrid")
#       2
#       3 heat_layer = gmaps.heatmap_layer(locations, weights=cities["Humidity"],dissipating=False, max_intensity=humidity_max,point_radius=1)
#       4 fig.add_layer(heat_layer)
#       5 fig
#
# ~\anaconda3\lib\site-packages\gmaps\figure.py in figure(display_toolbar, display_errors, zoom_level, tilt, center, layout, map_type, mouse_handling)
#     219         _map=_map, _toolbar=_toolbar, _errors_box=_errors_box,
#     220         layout=layout, map_type=map_type, tilt=tilt,
# --> 221         mouse_handling=mouse_handling)
#     222     return fig
#
# ~\anaconda3\lib\site-packages\gmaps\figure.py in __init__(self, *args, **kwargs)
#      49         if kwargs.get('layout') is None:
# ...

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
narrowdown_df = cities.loc[(cities["Max Temp"] > 70) & (cities["Max Temp"] < 80) & (cities ["Wind Speed"] < 10) & (cities["Cloudiness"] == 0), :]
narrowdown_df = narrowdown_df.dropna(how="any")
narrowdown_df.reset_index(inplace=True)
del narrowdown_df["index"]
narrowdown_df
# Out:
#            City  Cloudiness Country        Date  Humidity    Lat    Lng  \
# 0  ponta do sol           0      BR  1558378767        57 -20.63 -46.00
# 1      cidreira           0      BR  1558378770        66 -30.17 -50.22
# 2     morondava           0      MG  1558378780        69 -20.30  44.28
# 3         vaini           0      IN  1558378780        88  15.34  74.49
# 4         nador           0      MA  1558378499        40  35.17  -2.93
# 5         mogok           0      MM  1558378844        51  22.92  96.51
# 6       birjand           0      IR  1558378880        26  32.86  59.22
#
#    Max Temp  Wind Speed
# 0     73.68        5.32
# 1     76.56        5.50
# 2     79.08        9.06
# 3     78.90        1.59
# 4     75.20        6.93
# 5     72.24        2.77
# 6     71.60        9.17

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
hotel_list = []

for i in range(len(narrowdown_df)):
    lat = narrowdown_df.loc[i]["Lat"]
    lng = narrowdown_df.loc[i]["Lng"]
    
    prams = {
        "location": f"{lat},{lng}",
        "radius": 5000,
        "types": "hotel",
        "key": g_key
    }
    
    url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    requested = requests.get(url, params=prams)
    json = requested.json()
    try:
        hotel.append(jsn['results'][0]['name'])
    except:
        hotel_list.append("")
narrowdown_df["Hotel Name"] = hotel_list
narrowdown_df = narrowdown_df.dropna(how="any")
narrowdown_df
# Out:
#            City  Cloudiness Country        Date  Humidity    Lat    Lng  \
# 0  ponta do sol           0      BR  1558378767        57 -20.63 -46.00
# 1      cidreira           0      BR  1558378770        66 -30.17 -50.22
# 2     morondava           0      MG  1558378780        69 -20.30  44.28
# 3         vaini           0      IN  1558378780        88  15.34  74.49
# 4         nador           0      MA  1558378499        40  35.17  -2.93
# 5         mogok           0      MM  1558378844        51  22.92  96.51
# 6       birjand           0      IR  1558378880        26  32.86  59.22
#
#    Max Temp  Wind Speed Hotel Name
# 0     73.68        5.32
# 1     76.56        5.50
# 2     79.08        9.06
# 3     78.90        1.59
# 4     75.20        6.93
# 5     72.24        2.77
# 6     71.60        9.17

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in narrowdown_df.iterrows()]
locations = narrowdown_df[["Lat", "Lng"]]

# %%
# Add marker layer ontop of heat map
markers = gmaps.marker_layer(locations)
fig.add_layer(markers)
fig

# Display figure
# Out:
# Figure(layout=FigureLayout(height='420px'))
